# %%
# This is a pipeline of scRNAseq using the 500 top PCA loading genes

# %%
# Load the neccessary packages

library(biomaRt)
library(Rtsne)

# %%
# The table with highly variant genes that was crerated in the previous step (find_high_variant_genes)
cd <- read.csv('/home/rstudio/SingleCellProject/R_wdir/Final_data/highly_variant_genes_all_421.csv', header =T)
head(cd)
# Out:
#   ensembl_gene_id    meanNormCount P2272_1002 P2272_1004 P2272_1005 P2272_1006
# 1 ENSMUSG00000000001  120.03157    0.4001782   0.000000  0.5410561   9.6268420
# 2 ENSMUSG00000000031  395.52065    0.0000000   0.000000  0.2957449   0.2444772
# 3 ENSMUSG00000000056   35.20093    0.0000000   0.347601  4.8111995   0.0000000
# 4 ENSMUSG00000000058   97.65257    0.0000000   0.347601  0.0000000   0.0000000
# 5 ENSMUSG00000000078 2195.09250    1.8942175  12.449941  2.1416876  10.2835167
# 6 ENSMUSG00000000085   64.10177    0.0000000   0.000000  0.0000000   0.0000000
#   P2272_1009 P2272_1010 P2272_1012 P2272_1013 ⋯ P7657_1181 P7657_1182
# 1  0.2353862 0.000000   0.000000   0.000      ⋯  0.000000  0.000000
# 2  0.0000000 0.000000   0.000000   0.000      ⋯  0.000000  0.000000
# 3  3.5401897 2.194540   0.000000   0.000      ⋯  0.000000  0.000000
# 4  6.7339913 2.194540   0.000000   0.000      ⋯  0.000000  0.000000
# 5 11.3679732 3.241194   3.667244   2.824      ⋯ 13.066587  4.423441
# 6  0.0000000 0.000000   0.000000   0.000      ⋯  4.806537  7.404949
#   P7657_1184 P7657_1185 P7657_1186 P7657_1187 P7657_1188 P7657_1190 P7657_1191
# 1 7.222446    0.0000000  0.00000    0.000000  1.099182    7.1112922  0.00000
# 2 0.000000    0.0000000  0.00000    0.000000  0.000000    0.0000000  0.00000
# 3 0.000000    0.8720806  0.00000    0.000000  7.591798    0.0000000  0.00000
# 4 8.939290    0.0000000  0.00000    0.000000  0.000000    0.0000000 10.01437
# 5 4.371945   11.3693288 11.00682   10.776724  7.998535   11.8135870 11.43179
# 6 0.000000    8.6659992  0.00000    9.187439  0.000000    0.9909679  0.00000
#   P7657_1192
# 1 0.000000
# 2 0.000000
# 3 0.000000
# 4 8.566506
# 5 7.903257
# 6 7.326044

# %%
# Translate the ensembl_gene_ids to external gene names using the online biomaRt package
listMarts(host="www.ensembl.org")
ensembl = useMart(biomart = "ENSEMBL_MART_ENSEMBL",
                  dataset="mmusculus_gene_ensembl",
                  host = "oct2016.archive.ensembl.org")
cd <- read.csv('/home/rstudio/SingleCellProject/R_wdir/Final_data/highly_variant_genes_all_421.csv', header =T)
meta <- read.csv('/home/rstudio/SingleCellProject/R_wdir/Final_data/metadata_all_filtered_final_421.csv',row.names=1)
genes <- cd$ensembl_gene_id
gene.list <- getBM(filters= "ensembl_gene_id",
                             attributes= c("ensembl_gene_id",
                                           "external_gene_name"),
                                           values=genes,
                                           mart= ensembl)
gene.name <- merge(cd,gene.list, by = "ensembl_gene_id")
mat <- gene.name
# Out:
#   biomart              version
# 1 ENSEMBL_MART_ENSEMBL Ensembl Genes 88
# 2 ENSEMBL_MART_MOUSE   Mouse strains 88
# 3 ENSEMBL_MART_SNP     Ensembl Variation 88
# 4 ENSEMBL_MART_FUNCGEN Ensembl Regulation 88
# 5 ENSEMBL_MART_VEGA    Vega

# %%
# Some data filtering and reshaping
rownames(mat) <- mat[,424]
mat <- mat[,-424]
mat <- mat[,-1]
mat <- mat[,-1]

# %%
# Run a principal components analysis and take the 100 top loading features from each of the first 5 PCs
base.pca <- prcomp(t(mat))
tail=as.vector(apply(base.pca$rotation[,1:5],2,function(x) tail(names(sort(x)),n=50)))
head=as.vector(apply(base.pca$rotation[,1:5],2,function(x) head(names(sort(x)),n=50)))
top.load.genes = unique(c(head,tail))
top.load.genes <- as.data.frame(top.load.genes)

# %%
# Some more data reshaping
colnames(top.load.genes) <- 'external_gene_name'
top.500 <- merge(top.load.genes,gene.name,by='external_gene_name')

rownames(top.500) <- top.500[,1]
top.500 <- top.500[,-1]
top.500 <- top.500[,-1]
top.500 <- top.500[,-1]

# %%
# Run a TSNE using the 500 top loaging features

d <- stats::dist(t(top.500))
tsne_out <- Rtsne(d,
                  dims=2,
                  initial_dims=5,
                  is_distance=TRUE,
                  perplexity=32,
                  verbose = 2,
                  theta=0.1,pca=T)
# Out:
# Read the 421 x 421 data matrix successfully!
# Using no_dims = 2, perplexity = 32.000000, and theta = 0.100000
# Computing input similarities...
# Building tree...
#  - point 0 of 421
# Done in 0.17 seconds (sparsity = 0.315864)!
# Learning embedding...
# Iteration 50: error is 60.321062 (50 iterations in 0.36 seconds)
# Iteration 100: error is 58.161130 (50 iterations in 0.30 seconds)
# Iteration 150: error is 60.293074 (50 iterations in 0.29 seconds)
# Iteration 200: error is 60.170268 (50 iterations in 0.29 seconds)
# Iteration 250: error is 59.687774 (50 iterations in 0.29 seconds)
# Iteration 300: error is 1.102203 (50 iterations in 0.32 seconds)
# Iteration 350: error is 0.780670 (50 iterations in 0.30 seconds)
# Iteration 400: error is 0.755246 (50 iterations in 0.29 seconds)
# Iteration 450: error is 0.716703 (50 iterations in 0.28 seconds)
# Iteration 500: error is 0.711465 (50 iterations in 0.28 seconds)
# Iteration 550: error is 0.709890 (50 iterations in 0.28 seconds)
# Iteration 600: error is 0.709608 (50 iterations in 0.28 seconds)
# Iteration 650: error is 0.709513 (50 iterations in 0.28 seconds)
# Iteration 700: error is 0.709490 (50 iterations in 0.28 seconds)
# Iteration 750: error is 0.709476 (50 iterations in 0.28 seconds)
# Iteration 800: error is 0.709474 (50 iterations in 0.28 seconds)
# Iteration 850: error is 0.709469 (50 iterations in 0.28 seconds)
# Iteration 900: error is 0.709441 (50 iterations in 0.28 seconds)
# Iteration 950: error is 0.709430 (50 iterations in 0.28 seconds)
# Iteration 1000: error is 0.709437 (50 iterations in 0.29 seconds)
# Fitting performed in 5.81 seconds.

# %%
# Plot the results colored by the clusters derived from a previous step (clustering_analysis)

plot(tsne_out$Y[,1],tsne_out$Y[,2],pch = 20,xlab='tSNE_1',ylab='tSNE_2',
     col=c("darkgreen","grey","black","darkred","blue","orange","red")[as.numeric(meta$clusterboot2)],
     main='t-Distributed stochastic neighbor embedding')
# Out:
# Plot with title “t-Distributed stochastic neighbor embedding”

# %%
sessionInfo()
# Out:
# R version 3.3.1 (2016-06-21)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 16.04.1 LTS
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] Rtsne_0.11     biomaRt_2.30.0
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.10         AnnotationDbi_1.36.2 magrittr_1.5
#  [4] IRanges_2.8.2        BiocGenerics_0.20.0  uuid_0.1-2
#  [7] R6_2.2.0             stringr_1.2.0        tools_3.3.1
# [10] parallel_3.3.1       Biobase_2.34.0       DBI_0.6-1
# [13] digest_0.6.12        crayon_1.3.2         IRdisplay_0.4.9000
# [16] repr_0.10            S4Vectors_0.12.2     bitops_1.0-6
# [19] RCurl_1.95-4.8       IRkernel_0.6         memoise_1.0.0
# [22] evaluate_0.10        RSQLite_1.1-2        pbdZMQ_0.2-5
# [25] stringi_1.1.3        stats4_3.3.1         XML_3.98-1.6
# [28] jsonlite_1.3
